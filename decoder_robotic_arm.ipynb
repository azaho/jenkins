# %%
import numpy as np
from ikpy.chain import Chain
from ikpy.link import OriginLink, URDFLink
from dynamixel_sdk import PortHandler, PacketHandler

joint7 = URDFLink(
    name="7_base_rotation",
    origin_translation=np.array([0, 0, 0.038]),  # 38 mm upward from base
    origin_orientation=np.array([0, 0, 0]),
    rotation=np.array([0, 0, 1]),
    joint_type="revolute",
    bounds=(0, 3*np.pi/2)
)

# Joint 8: Shoulder tilt (rotates about y, here using [0, -1, 0])
joint8 = URDFLink(
    name="8_shoulder_tilt",
    origin_translation=np.array([0, 0, 0.017]),  # 17 mm upward from Joint 7
    origin_orientation=np.array([0, 0, 0]),
    rotation=np.array([0, 1, 0]),
    joint_type="revolute",
    bounds=(-.65, np.pi/2)
)

# Joint 9: Elbow tilt (rotates about y)
L2 = 0.110  # 110 mm from Joint 8
joint9 = URDFLink(
    name="9_elbow_tilt",
    origin_translation=np.array([0, 0, L2]),
    origin_orientation=np.array([0, 0, 0]),
    rotation=np.array([0, 1, 0]),
    joint_type="revolute",
    bounds=(-110 / 180 * np.pi, 1.4)
)

# Joint 10: Wrist tilt (rotates about y)
L3 = 0.100  # 100 mm from Joint 9
joint10 = URDFLink(
    name="10_wrist_tilt",
    origin_translation=np.array([L3, 0, 0]),
    origin_orientation=np.array([0, 0, 0]),
    rotation=np.array([0, -1, 0]),
    joint_type="revolute",
    bounds=(-np.pi/2, np.pi/2)
)

# Joint 11: Gripper rotate (rotates about z)
L4 = 0.120 # 45 mm from Joint 10
joint11 = URDFLink(
    name="11_gripper_rotate",
    origin_translation=np.array([0, 0, -L4]),
    origin_orientation=np.array([0, 0, 0]),
    rotation=np.array([1, 0, 0]),
    joint_type="revolute"
)

# Assemble the robot chain: The first link is the fixed base (OriginLink)
robot_chain_follower = Chain(name="robot_chain_follower", links=[
    OriginLink(),
    joint7,
    joint8,
    joint9,
    joint10,
    joint11
])

PROTOCOL_VERSION = 2.0
DXL_IDS = [7, 8, 9, 10, 11, 12]  # Use first 5 IDs for joints 7-11.
BAUDRATE = 1e6
DEVICENAME = '/dev/ttyACM0'
# sudo chmod 777 /dev/ttyACM0

TICKS_PER_REV = 4096

def rad_to_dxl(angle_rad):
    angle_rad = angle_rad
    return int((angle_rad / (2 * np.pi)) * TICKS_PER_REV)

def dxl_to_rad(ticks):
    return (ticks / TICKS_PER_REV) * 2 * np.pi

# ----------------------------
# Initialize Port and Packet Handler (No torque enable required here)
# ----------------------------
port_handler = PortHandler(DEVICENAME)
packet_handler = PacketHandler(PROTOCOL_VERSION)
if not port_handler.openPort():
    print("Failed to open port!")
    exit()
if not port_handler.setBaudRate(BAUDRATE):
    print("Failed to set baudrate!")
    exit()

def to_signed(val):
    if val > 0x7FFFFFFF:  # 0x7FFFFFFF is 2^31 - 1
        return val - 0x100000000  # 0x100000000 is 2^32
    return val

# ----------------------------
# Read Current Angles Function
# ----------------------------
def read_current_angles_follower():
    angles = []
    for dxl_id in DXL_IDS[:5]:  # Only for joints 7-11
        pos, dxl_comm_result, dxl_error = packet_handler.read4ByteTxRx(port_handler, dxl_id, 132)
        # print("ID", dxl_id, "TICKS", pos)
        if dxl_comm_result != 0 or dxl_error != 0:
            print(f"Error reading servo {dxl_id}, assuming 0.")
            angles.append(0)
        else:
            angle = dxl_to_rad(to_signed(pos))
            # print("RAW POS", pos)
            # print("SIGNED POS", to_signed(pos))
            angles.append(angle)
    return np.array(angles)


def forward_kinematics_follower(angles):
    truncated = angles[:5]  # angles for joints 7-11
    full_angles = np.concatenate(([0], truncated))  # Prepend dummy for OriginLink
    return robot_chain_follower.forward_kinematics(full_angles)

current_angles = read_current_angles_follower()
print("Current joint angles (deg) from servos:", current_angles*180/ (np.pi))
print("Current joint angles (rad) from servos:", current_angles)

home_pose = forward_kinematics_follower(current_angles)
home_xyz = home_pose[:3, 3] * 100  # Convert from meters to centimeters

print("\nHome position (xyz) of end-effector (joint 11) relative to base (in cm):")
print(f"  x = {home_xyz[0]:.2f} cm")
print(f"  y = {home_xyz[1]:.2f} cm")
print(f"  z = {home_xyz[2]:.2f} cm")

port_handler.closePort()
# Out:
# Error reading servo 7, assuming 0.
# Error reading servo 8, assuming 0.
# Error reading servo 9, assuming 0.
# Error reading servo 10, assuming 0.
# Error reading servo 11, assuming 0.
# Current joint angles (deg) from servos: [0. 0. 0. 0. 0.]
# Current joint angles (rad) from servos: [0 0 0 0 0]
#
# Home position (xyz) of end-effector (joint 11) relative to base (in cm):
#   x = 10.00 cm
#   y = 0.00 cm
#   z = 4.50 cm

# %%
#======MOVE
import numpy as np
import time
from ikpy.chain import Chain
from ikpy.link import OriginLink, URDFLink
from dynamixel_sdk import PortHandler, PacketHandler

# ----------------------------
# Initialize Port and Packet Handler, and enable torque
# ----------------------------
port_handler = PortHandler(DEVICENAME)
packet_handler = PacketHandler(PROTOCOL_VERSION)

def to_unsigned(val):
    if val < 0:
        return val + 0x100000000  # 0x100000000 is 2^32
    return val


if not port_handler.openPort():
    print("Failed to open port!")
    exit()
if not port_handler.setBaudRate(BAUDRATE):
    print("Failed to set baudrate!")
    exit()

# Enable torque on servos for joints 7-11 (first 5 IDs)
TORQUE_ENABLE_ADDR = 64  # Typical address for torque enable in protocol 2.0
TORQUE_ENABLE_VALUE = 1
for dxl_id in DXL_IDS[:5]:
    comm_result, error = packet_handler.write1ByteTxRx(port_handler, dxl_id, TORQUE_ENABLE_ADDR, TORQUE_ENABLE_VALUE)
    if comm_result != 0 or error != 0:
        print(f"Error enabling torque for servo {dxl_id}: {comm_result}, {error}")
    else:
        print(f"Torque enabled for servo {dxl_id}")

# ----------------------------
# Function to Read Current Angles (radians) from Servos (joints 7-11)
# ----------------------------
def read_current_angles():
    angles = []
    for dxl_id in DXL_IDS[:5]:
        pos, comm_result, error = packet_handler.read4ByteTxRx(port_handler, dxl_id, 132)
        if comm_result != 0 or error != 0:
            print(f"Error reading servo {dxl_id}, assuming 0.")
            angles.append(0)
        else:
            angles.append(dxl_to_rad(to_signed(pos)))
    return np.array(angles)

# ----------------------------
# Forward Kinematics Function for Chain Up to Joint 11
# ----------------------------
def forward_kinematics_11(angles):
    """
    Computes FK for joints 7-11.
    Prepend a dummy value (0) for the base (OriginLink) and compute the 4x4 pose.
    """
    full_angles = np.concatenate(([0], angles))
    return robot_chain_11.forward_kinematics(full_angles)

# ----------------------------
# Build a Target Pose (in meters)
# ----------------------------
def build_target_pose(x, y, z):
    pose = np.eye(4)
    pose[:3, 3] = np.array([x, y, z])
    return pose

# ----------------------------
# Move to a Target Based on Current Position (using current configuration as initial guess)
# ----------------------------hand_to_neuro_mlpse element at index 0).
    desired_angles = ik_solution[1:6]
    
    print("\nCalculated joint angles (radians) for target position:")
    # Print the angles directly in radians.
    # for i, angle in enumerate(desired_angles):
    #     print(f"  Joint {7+i}: {angle*180/np.pi} degree")
    
    # Command servos (for joints 7-11) using the computed angles.
    for i, dxl_id in enumerate(DXL_IDS[:5]):
        target_tick = to_unsigned(rad_to_dxl(desired_angles[i]))
        print("WRITING TICKS SIGNED: ", rad_to_dxl(desired_angles[i]))
        print("TICKS UNSIGNED", target_tick)
        
        comm_result, error = packet_handler.write4ByteTxRx(port_handler, dxl_id, 116, target_tick)
        if comm_result != 0 or error != 0:
            print(f"Error sending command to servo {dxl_id}: {comm_result}, {error}")
        else:
            print(f"Servo {dxl_id} commanded to {desired_angles[i]:.3f} rad ({target_tick} ticks)")
    
    # Read back new servo angles and compute the new end-effector pose.
    # new_angles = read_current_angles()
    # new_pose = forward_kinematics_11(new_angles)
    # new_xyz = new_pose[:3, 3] * 100  # convert from m to cm
    # print("\nNew end-effector position (cm):")
    # print(f"  x = {new_xyz[0]:.2f} cm, y = {new_xyz[1]:.2f} cm, z = {new_xyz[2]:.2f} cm")

# ----------------------------
# Main Interactive Loop
# ----------------------------
# def main_loop():
#     while True:
#         current_angles = read_current_angles()
#         current_pose = forward_kinematics_11(current_angles)
#         current_xyz = current_pose[:3, 3] * 100  # in cm
#         print("\nCurrent end-effector position (cm):")
#         print(f"  x = {current_xyz[0]:.2f} cm, y = {current_xyz[1]:.2f} cm, z = {current_xyz[2]:.2f} cm")
        
#         user_input = input("\nEnter new target coordinates (x y z in cm), or 'q' to quit: ")
#         if user_input.strip().lower() == 'q':
#             break
#         try:
#             tx, ty, tz = map(float, user_input.strip().split())
#         except Exception:
#             print("Invalid input. Please enter three numbers separated by spaces.")
#             continue
        
#         move_to_target_from_current(tx, ty, tz)
    
#     port_handler.closePort()
#     print("Port closed. Exiting.")

# if __name__ == '__main__':
#     main_loop()
# Out:
# Torque enabled for servo 7
# Torque enabled for servo 8
# Torque enabled for servo 9
# Torque enabled for servo 10
# Torque enabled for servo 11

# %%
import torch
from decoder_SingleSessionSingleTrialDataset import SingleSessionSingleTrialDataset
import numpy as np
from pynwb import NWBHDF5IO

import os

dataset_path = "000070"
nwb_file_path = os.path.join(
    dataset_path, "sub-Jenkins", "sub-Jenkins_ses-20090916_behavior+ecephys.nwb")
#nwb_file_path = "sub-Jenkins_ses-20090916_behavior+ecephys.nwb"
io = NWBHDF5IO(nwb_file_path, 'r')
nwb_file = io.read()
hand_data = nwb_file.processing['behavior'].data_interfaces['Position']['Hand'].data[:]
hand_timestamps = nwb_file.processing['behavior'].data_interfaces['Position']['Hand'].timestamps[:]
trial_data = nwb_file.intervals['trials']

unit_spike_times = [nwb_file.units[unit_id]['spike_times'].iloc[0][:]
                    for unit_id in range(len(nwb_file.units))]
n_neurons = len(unit_spike_times)
n_context_bins = 50

trials_start_from = int(2000 * 0.9)
n_trials = int(2000 * 0.1)
datasets = [SingleSessionSingleTrialDataset(
    trial_data, hand_data, hand_timestamps, unit_spike_times, trial_id, bin_size=0.02, n_context_bins=n_context_bins) for trial_id in range(trials_start_from, trials_start_from + n_trials)]
dataset = torch.utils.data.ConcatDataset(datasets)
print(f"Dataset from {n_trials} trials has {len(dataset)} samples")
# Out:
# /home/dima/code/marvin/venv/lib/python3.10/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.3.0 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /home/dima/code/marvin/venv/lib/python3.10/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'core' version 2.2.5 because version 2.7.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# Dataset from 200 trials has 20418 samples

# %%
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

# Convert dataset to PyTorch tensors and move to GPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
X = []
y = []
for i in range(len(dataset)):
    features, labels = dataset[i]
    print(features)
    X.append(features[:].flatten())
    y.append(labels)
X_test = torch.stack(X).to(device)
y_test = torch.stack(y).to(device)

# Define model
input_size = n_neurons * n_context_bins
model = nn.Sequential(
    nn.Linear(input_size, 256),
    nn.ReLU(),
    nn.Linear(256, 128),
    nn.ReLU(),
    nn.Linear(128, 2)
).to(device)

# Load the trained model
model.load_state_dict(torch.load('decoder_mlp.pth'))
model.eval()  # Set the model to evaluation mode

# %%
import pygame
import numpy as np
import time

# Initialize Pygame
pygame.init()

# # Set up display
screen = pygame.display.set_mode((0, 0), pygame.FULLSCREEN)
WIDTH, HEIGHT = screen.get_size()
# Set up display
# WIDTH = 1200
# HEIGHT = 800  # Increased height to accommodate velocity plots
# screen = pygame.display.set_mode((WIDTH, HEIGHT))

pygame.display.set_caption("Neural Spike Train and Velocity Visualization")

# Colors
BLACK = (0, 0, 0)
GRAY = (140, 140, 140)  # For grid lines
WHITE = (255, 255, 255)
DARK_GRAY = (40, 40, 40)  # Darker gray for velocity lines

# X offset for plots
X_OFFSET = 45

# Get spike data
spike_data = X_test.reshape(-1, n_neurons, n_context_bins)[:, :, -1].T
total_bins = spike_data.shape[1]
window_size = 500
bin_step = 1  # Number of bins to advance each frame (1 bin = 20ms)

# Get model predictions
y_pred = model(torch.tensor(X_test, dtype=torch.float32)).detach().numpy()
y_true = y_test.detach().numpy()

# Normalize predictions and true values to have mean 1
y_pred = y_pred / np.mean(np.abs(y_pred))
y_true = y_true / np.mean(np.abs(y_true))

# Calculate scaling factors
spike_plot_height = HEIGHT // 4 * 3
neuron_height = spike_plot_height // n_neurons
time_bin_width = WIDTH // window_size
plot_height = HEIGHT // 10  # Reduced height for each velocity plot

# Normalize spike data for color intensity
spike_data_normalized = (spike_data - spike_data.min()) / (spike_data.max() - spike_data.min())
spike_data_normalized = spike_data_normalized.detach().numpy()

# Create font for labels
font = pygame.font.SysFont('arial', 24)

def normalize_for_plot(value, height):
    # Normalize values to fit in plot height
    return height // 2 + (value * height // 28)

running = True
current_bin = 0
clock = pygame.time.Clock()

# Pre-create surface for spike data
spike_surface = pygame.Surface((WIDTH, spike_plot_height))

while running:
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False
        elif event.type == pygame.KEYDOWN:
            if event.key == pygame.K_ESCAPE:  # Add escape key to exit
                running = False
            
    # Clear screen
    screen.fill(BLACK)
    spike_surface.fill(BLACK)
    
    # Draw spike trains first using numpy operations
    if current_bin + window_size <= total_bins:
        # Get the current window of spike data
        window_data = spike_data_normalized[:, current_bin:current_bin+window_size]
        
        # Convert to pixel values (0-255)
        pixel_values = np.minimum(window_data * 255 * 1.5, 255).astype(np.uint8)
        
        # Create a surface from the numpy array
        for neuron in range(n_neurons):
            row_data = pixel_values[neuron]
            for t, intensity in enumerate(row_data):
                if intensity > 0:  # Only draw if there's activity
                    pygame.draw.rect(spike_surface, (intensity, intensity, intensity),
                                   (X_OFFSET + t * time_bin_width, neuron * neuron_height,
                                    time_bin_width, neuron_height))
    
    # Draw the spike surface to the screen
    screen.blit(spike_surface, (0, 0))
    
    # Draw grid lines and channel numbers on top
    for i in range(0, spike_plot_height, neuron_height * n_neurons):  # Draw every 200 channels
        pygame.draw.line(screen, GRAY, (X_OFFSET, i), (WIDTH, i), 1)
        # Draw channel number
        label = font.render(str(i // neuron_height), True, WHITE)
        # Rotate the label surface
        rotated_label = pygame.transform.rotate(label, 90)
        screen.blit(rotated_label, (10, i))
    
    # Draw velocity plots
    y_offset = spike_plot_height - 80  # Start below spike plot
    
    # Draw X velocity plot
    pygame.draw.line(screen, DARK_GRAY, (X_OFFSET, y_offset + plot_height//2), (WIDTH, y_offset + plot_height//2), 1)
    
    # Pre-calculate positions for velocity plots
    if current_bin + window_size <= len(y_true):
        t_range = np.arange(window_size-1)
        x_coords = X_OFFSET + t_range * time_bin_width
        x_coords_next = X_OFFSET + (t_range + 1) * time_bin_width
        
        # X velocity
        true_y_x = y_offset + normalize_for_plot(y_true[current_bin:current_bin+window_size-1, 0], plot_height)
        true_y_x_next = y_offset + normalize_for_plot(y_true[current_bin+1:current_bin+window_size, 0], plot_height)
        pred_y_x = y_offset + normalize_for_plot(y_pred[current_bin:current_bin+window_size-1, 0], plot_height)
        pred_y_x_next = y_offset + normalize_for_plot(y_pred[current_bin+1:current_bin+window_size, 0], plot_height)
        
        # Draw lines in batches
        for i in range(len(x_coords)):
            pygame.draw.line(screen, GRAY, 
                           (int(x_coords[i]), int(true_y_x[i])), 
                           (int(x_coords_next[i]), int(true_y_x_next[i])), 2)
            pygame.draw.line(screen, WHITE,
                           (int(x_coords[i]), int(pred_y_x[i])),
                           (int(x_coords_next[i]), int(pred_y_x_next[i])), 2)
    
    # Draw Y velocity plot
    y_offset += plot_height + 110
    pygame.draw.line(screen, DARK_GRAY, (X_OFFSET, y_offset + plot_height//2), (WIDTH, y_offset + plot_height//2), 1)
    
    if current_bin + window_size <= len(y_true):
        # Y velocity
        true_y_y = y_offset + normalize_for_plot(y_true[current_bin:current_bin+window_size-1, 1], plot_height)
        true_y_y_next = y_offset + normalize_for_plot(y_true[current_bin+1:current_bin+window_size, 1], plot_height)
        pred_y_y = y_offset + normalize_for_plot(y_pred[current_bin:current_bin+window_size-1, 1], plot_height)
        pred_y_y_next = y_offset + normalize_for_plot(y_pred[current_bin+1:current_bin+window_size, 1], plot_height)
        
        # Draw lines in batches
        for i in range(len(x_coords)):
            pygame.draw.line(screen, GRAY,
                           (int(x_coords[i]), int(true_y_y[i])),
                           (int(x_coords_next[i]), int(true_y_y_next[i])), 2)
            pygame.draw.line(screen, WHITE,
                           (int(x_coords[i]), int(pred_y_y[i])),
                           (int(x_coords_next[i]), int(pred_y_y_next[i])), 2)
    
    # Draw axis labels
    time_label = font.render("Time", True, WHITE)
    channels_label = font.render("Channels", True, WHITE)
    x_vel_label = font.render("velocity X (prediction: WHITE)", True, WHITE)
    y_vel_label = font.render("velocity Y (prediction: WHITE)", True, WHITE)
    
    screen.blit(time_label, (WIDTH // 2 - 30, HEIGHT - 30))
    screen.blit(x_vel_label, (WIDTH // 2 - 150, spike_plot_height - 90))
    screen.blit(y_vel_label, (WIDTH // 2 - 150, spike_plot_height + plot_height - 15))
    
    # Rotate and draw y-axis label
    channels_surface = pygame.Surface((200, 30))
    channels_surface.fill(BLACK)
    channels_surface.blit(channels_label, (50, 0))
    channels_surface = pygame.transform.rotate(channels_surface, 90)
    screen.blit(channels_surface, (10, spike_plot_height // 2 - 100))
    
    # Update display
    pygame.display.flip()
    
    # Move window by one bin (20ms) each frame
    current_bin += bin_step
    if current_bin + window_size > total_bins:
        current_bin = 0

    if current_bin % 2 == 0:
        lambda_decay = 0.9  # Exponential decay factor
        integrated_v = np.zeros(2)
        for i in range(current_bin + window_size):
            integrated_v = lambda_decay * integrated_v + y_pred[i]
        integrated_v = integrated_v / 70
        integrated_v = integrated_v.clip(-1, 1)
        integrated_v = integrated_v * 15
        print(integrated_v)
        # now integrated v is always in the window -10cm to 10cm
        x, y = integrated_v[0], integrated_v[1]

        current_angles = read_current_angles()
        # current_pose = forward_kinematics_11(current_angles)
        # current_xyz = current_pose[:3, 3] * 100  # in cm
        # print("\nCurrent end-effector position (cm):")
        # print(f"  x = {current_xyz[0]:.2f} cm, y = {current_xyz[1]:.2f} cm, z = {current_xyz[2]:.2f} cm")

        move_to_target_from_current(25, x, y+20, current_angles=current_angles)
        
    # Control frame rate to 50 FPS (20ms per frame)
    #clock.tick(50)

pygame.quit()
# Out:
# /tmp/ipykernel_7891/1479401448.py:34: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_pred = model(torch.tensor(X_test, dtype=torch.float32)).detach().numpy()
# [ 1.40974689 -1.26241163]
# Current joint angles (radians): [179.12109375  20.7421875   26.27929688  63.36914062  11.6015625 ]
# Target pose matrix (meters):
# [[1.         0.         0.         0.25      ]
#  [0.         1.         0.         0.01409747]
#  [0.         0.         1.         0.18737588]
#  [0.         0.         0.         1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2084
# TICKS UNSIGNED 2084
# Servo 7 commanded to 3.198 rad (2084 ticks)
# WRITING TICKS SIGNED:  179
# TICKS UNSIGNED 179
# Servo 8 commanded to 0.275 rad (179 ticks)
# WRITING TICKS SIGNED:  204
# TICKS UNSIGNED 204
# Servo 9 commanded to 0.314 rad (204 ticks)
# WRITING TICKS SIGNED:  734
# TICKS UNSIGNED 734
# Servo 10 commanded to 1.127 rad (734 ticks)
# WRITING TICKS SIGNED:  132
# TICKS UNSIGNED 132
# Servo 11 commanded to 0.202 rad (132 ticks)
# [ 1.07126678 -1.06648325]
# Current joint angles (radians): [181.66992188  20.30273438  26.27929688  63.36914062  11.6015625 ]
# Target pose matrix (meters):
# [[1.         0.         0.         0.25      ]
#  [0.         1.         0.         0.01071267]
#  [0.         0.         1.         0.18933517]
#  [0.         0.         0.         1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2075
# TICKS UNSIGNED 2075
# Servo 7 commanded to 3.184 rad (2075 ticks)
# WRITING TICKS SIGNED:  179
# TICKS UNSIGNED 179
# Servo 8 commanded to 0.275 rad (179 ticks)
# WRITING TICKS SIGNED:  198
# TICKS UNSIGNED 198
# Servo 9 commanded to 0.304 rad (198 ticks)
# WRITING TICKS SIGNED:  733
# TICKS UNSIGNED 733
# Servo 10 commanded to 1.126 rad (733 ticks)
# WRITING TICKS SIGNED:  132
# TICKS UNSIGNED 132
# Servo 11 commanded to 0.202 rad (132 ticks)
# [ 0.8065548  -0.91857738]
# Current joint angles (radians): [182.4609375   20.30273438  26.27929688  63.36914062  11.6015625 ]
# Target pose matrix (meters):
# [[1.         0.         0.         0.25      ]
#  [0.         1.         0.         0.00806555]
#  [0.         0.         1.         0.19081423]
#  [0.         0.         0.         1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2069
# TICKS UNSIGNED 2069
# Servo 7 commanded to 3.174 rad (2069 ticks)
# WRITING TICKS SIGNED:  179
# TICKS UNSIGNED 179
# Servo 8 commanded to 0.275 rad (179 ticks)
# WRITING TICKS SIGNED:  193
# TICKS UNSIGNED 193
# Servo 9 commanded to 0.297 rad (193 ticks)
# WRITING TICKS SIGNED:  732
# TICKS UNSIGNED 732
# Servo 10 commanded to 1.124 rad (732 ticks)
# WRITING TICKS SIGNED:  132
# TICKS UNSIGNED 132
# Servo 11 commanded to 0.202 rad (132 ticks)
# [ 0.62809006 -0.79026009]
# Current joint angles (radians): [181.93359375  20.30273438  26.27929688  63.36914062  11.6015625 ]
# Target pose matrix (meters):
# [[1.        0.        0.        0.25     ]
#  [0.        1.        0.        0.0062809]
#  [0.        0.        1.        0.1920974]
#  [0.        0.        0.        1.       ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2064
# TICKS UNSIGNED 2064
# Servo 7 commanded to 3.167 rad (2064 ticks)
# WRITING TICKS SIGNED:  178
# TICKS UNSIGNED 178
# Servo 8 commanded to 0.275 rad (178 ticks)
# WRITING TICKS SIGNED:  188
# TICKS UNSIGNED 188
# Servo 9 commanded to 0.290 rad (188 ticks)
# WRITING TICKS SIGNED:  731
# TICKS UNSIGNED 731
# Servo 10 commanded to 1.122 rad (731 ticks)
# WRITING TICKS SIGNED:  132
# TICKS UNSIGNED 132
# Servo 11 commanded to 0.202 rad (132 ticks)
# [ 0.44523294 -0.68595007]
# Current joint angles (radians): [181.58203125  20.30273438  26.27929688  63.36914062  11.6015625 ]
# Target pose matrix (meters):
# [[1.         0.         0.         0.25      ]
#  [0.         1.         0.         0.00445233]
#  [0.         0.         1.         0.1931405 ]
#  [0.         0.         0.         1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2059
# TICKS UNSIGNED 2059
# Servo 7 commanded to 3.159 rad (2059 ticks)
# WRITING TICKS SIGNED:  178
# TICKS UNSIGNED 178
# Servo 8 commanded to 0.275 rad (178 ticks)
# WRITING TICKS SIGNED:  185
# TICKS UNSIGNED 185
# Servo 9 commanded to 0.284 rad (185 ticks)
# WRITING TICKS SIGNED:  730
# TICKS UNSIGNED 730
# Servo 10 commanded to 1.120 rad (730 ticks)
# WRITING TICKS SIGNED:  132
# TICKS UNSIGNED 132
# Servo 11 commanded to 0.202 rad (132 ticks)
# [ 0.29923902 -0.59215625]
# Current joint angles (radians): [181.14257812  20.30273438  26.27929688  63.36914062  11.6015625 ]
# Target pose matrix (meters):
# [[1.         0.         0.         0.25      ]
#  [0.         1.         0.         0.00299239]
#  [0.         0.         1.         0.19407844]
#  [0.         0.         0.         1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2055
# TICKS UNSIGNED 2055
# Servo 7 commanded to 3.154 rad (2055 ticks)
# WRITING TICKS SIGNED:  179
# TICKS UNSIGNED 179
# Servo 8 commanded to 0.275 rad (179 ticks)
# WRITING TICKS SIGNED:  181
# TICKS UNSIGNED 181
# Servo 9 commanded to 0.278 rad (181 ticks)
# WRITING TICKS SIGNED:  729
# TICKS UNSIGNED 729
# Servo 10 commanded to 1.118 rad (729 ticks)
# WRITING TICKS SIGNED:  132
# TICKS UNSIGNED 132
# Servo 11 commanded to 0.202 rad (132 ticks)
# [ 0.22043271 -0.50534283]
# Current joint angles (radians): [180.61523437  20.30273438  26.27929688  63.36914062  11.6015625 ]
# Target pose matrix (meters):
# [[1.         0.         0.         0.25      ]
#  [0.         1.         0.         0.00220433]
#  [0.         0.         1.         0.19494657]
#  [0.         0.         0.         1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2053
# TICKS UNSIGNED 2053
# Servo 7 commanded to 3.150 rad (2053 ticks)
# WRITING TICKS SIGNED:  179
# TICKS UNSIGNED 179
# Servo 8 commanded to 0.275 rad (179 ticks)
# WRITING TICKS SIGNED:  178
# TICKS UNSIGNED 178
# Servo 9 commanded to 0.273 rad (178 ticks)
# WRITING TICKS SIGNED:  728
# TICKS UNSIGNED 728
# Servo 10 commanded to 1.117 rad (728 ticks)
# WRITING TICKS SIGNED:  132
# TICKS UNSIGNED 132
# Servo 11 commanded to 0.202 rad (132 ticks)
# [ 0.11718858 -0.49062569]
# Current joint angles (radians): [180.43945312  20.30273438  26.27929688  63.36914062  11.6015625 ]
# Target pose matrix (meters):
# [[1.         0.         0.         0.25      ]
#  [0.         1.         0.         0.00117189]
#  [0.         0.         1.         0.19509374]
#  [0.         0.         0.         1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2051
# TICKS UNSIGNED 2051
# Servo 7 commanded to 3.146 rad (2051 ticks)
# WRITING TICKS SIGNED:  179
# TICKS UNSIGNED 179
# Servo 8 commanded to 0.275 rad (179 ticks)
# WRITING TICKS SIGNED:  177
# TICKS UNSIGNED 177
# Servo 9 commanded to 0.272 rad (177 ticks)
# WRITING TICKS SIGNED:  727
# TICKS UNSIGNED 727
# Servo 10 commanded to 1.117 rad (727 ticks)
# WRITING TICKS SIGNED:  132
# TICKS UNSIGNED 132
# Servo 11 commanded to 0.202 rad (132 ticks)
# [ 0.04691    -0.47524525]
# Current joint angles (radians): [180.26367188  20.30273438  26.27929688  63.36914062  11.6015625 ]
# Target pose matrix (meters):
# [[1.00000000e+00 0.00000000e+00 0.00000000e+00 2.50000000e-01]
#  [0.00000000e+00 1.00000000e+00 0.00000000e+00 4.69100018e-04]
#  [0.00000000e+00 0.00000000e+00 1.00000000e+00 1.95247548e-01]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 1.00000000e+00]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2049
# TICKS UNSIGNED 2049
# Servo 7 commanded to 3.143 rad (2049 ticks)
# WRITING TICKS SIGNED:  179
# TICKS UNSIGNED 179
# Servo 8 commanded to 0.275 rad (179 ticks)
# WRITING TICKS SIGNED:  177
# TICKS UNSIGNED 177
# Servo 9 commanded to 0.272 rad (177 ticks)
# WRITING TICKS SIGNED:  727
# TICKS UNSIGNED 727
# Servo 10 commanded to 1.116 rad (727 ticks)
# WRITING TICKS SIGNED:  132
# TICKS UNSIGNED 132
# Servo 11 commanded to 0.202 rad (132 ticks)
# [ 0.02759676 -0.44491948]
# Current joint angles (radians): [180.08789062  20.30273438  26.27929688  63.36914062  11.6015625 ]
# Target pose matrix (meters):
# [[1.00000000e+00 0.00000000e+00 0.00000000e+00 2.50000000e-01]
#  [0.00000000e+00 1.00000000e+00 0.00000000e+00 2.75967559e-04]
#  [0.00000000e+00 0.00000000e+00 1.00000000e+00 1.95550805e-01]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 1.00000000e+00]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2048
# TICKS UNSIGNED 2048
# Servo 7 commanded to 3.143 rad (2048 ticks)
# WRITING TICKS SIGNED:  179
# TICKS UNSIGNED 179
# Servo 8 commanded to 0.275 rad (179 ticks)
# WRITING TICKS SIGNED:  175
# TICKS UNSIGNED 175
# Servo 9 commanded to 0.270 rad (175 ticks)
# WRITING TICKS SIGNED:  727
# TICKS UNSIGNED 727
# Servo 10 commanded to 1.116 rad (727 ticks)
# WRITING TICKS SIGNED:  132
# TICKS UNSIGNED 132
# Servo 11 commanded to 0.202 rad (132 ticks)
# [-0.00352655 -0.42150585]
# Current joint angles (radians): [180.          20.30273438  26.27929688  63.36914062  11.6015625 ]
# Target pose matrix (meters):
# [[ 1.00000000e+00  0.00000000e+00  0.00000000e+00  2.50000000e-01]
#  [ 0.00000000e+00  1.00000000e+00  0.00000000e+00 -3.52655002e-05]
#  [ 0.00000000e+00  0.00000000e+00  1.00000000e+00  1.95784941e-01]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2047
# TICKS UNSIGNED 2047
# Servo 7 commanded to 3.141 rad (2047 ticks)
# WRITING TICKS SIGNED:  179
# TICKS UNSIGNED 179
# Servo 8 commanded to 0.275 rad (179 ticks)
# WRITING TICKS SIGNED:  174
# TICKS UNSIGNED 174
# Servo 9 commanded to 0.268 rad (174 ticks)
# WRITING TICKS SIGNED:  726
# TICKS UNSIGNED 726
# Servo 10 commanded to 1.115 rad (726 ticks)
# WRITING TICKS SIGNED:  132
# TICKS UNSIGNED 132
# Servo 11 commanded to 0.202 rad (132 ticks)
# [-0.05201037 -0.39542967]
# Current joint angles (radians): [179.91210938  20.30273438  26.27929688  63.36914062  11.6015625 ]
# Target pose matrix (meters):
# [[ 1.00000000e+00  0.00000000e+00  0.00000000e+00  2.50000000e-01]
#  [ 0.00000000e+00  1.00000000e+00  0.00000000e+00 -5.20103719e-04]
#  [ 0.00000000e+00  0.00000000e+00  1.00000000e+00  1.96045703e-01]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2046
# TICKS UNSIGNED 2046
# Servo 7 commanded to 3.140 rad (2046 ticks)
# WRITING TICKS SIGNED:  179
# TICKS UNSIGNED 179
# Servo 8 commanded to 0.275 rad (179 ticks)
# WRITING TICKS SIGNED:  173
# TICKS UNSIGNED 173
# Servo 9 commanded to 0.267 rad (173 ticks)
# WRITING TICKS SIGNED:  726
# TICKS UNSIGNED 726
# Servo 10 commanded to 1.115 rad (726 ticks)
# WRITING TICKS SIGNED:  132
# TICKS UNSIGNED 132
# Servo 11 commanded to 0.202 rad (132 ticks)
# [-0.06878941 -0.32822212]
# Current joint angles (radians): [179.82421875  20.30273438  26.27929688  63.36914062  11.6015625 ]
# Target pose matrix (meters):
# [[ 1.00000000e+00  0.00000000e+00  0.00000000e+00  2.50000000e-01]
#  [ 0.00000000e+00  1.00000000e+00  0.00000000e+00 -6.87894079e-04]
#  [ 0.00000000e+00  0.00000000e+00  1.00000000e+00  1.96717779e-01]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2046
# TICKS UNSIGNED 2046
# Servo 7 commanded to 3.139 rad (2046 ticks)
# WRITING TICKS SIGNED:  179
# TICKS UNSIGNED 179
# Servo 8 commanded to 0.275 rad (179 ticks)
# WRITING TICKS SIGNED:  171
# TICKS UNSIGNED 171
# Servo 9 commanded to 0.263 rad (171 ticks)
# WRITING TICKS SIGNED:  725
# TICKS UNSIGNED 725
# Servo 10 commanded to 1.113 rad (725 ticks)
# WRITING TICKS SIGNED:  132
# TICKS UNSIGNED 132
# Servo 11 commanded to 0.202 rad (132 ticks)
# [-0.0831493  -0.27390326]
# Current joint angles (radians): [179.82421875  20.30273438  26.27929688  63.36914062  11.6015625 ]
# Target pose matrix (meters):
# [[ 1.00000000e+00  0.00000000e+00  0.00000000e+00  2.50000000e-01]
#  [ 0.00000000e+00  1.00000000e+00  0.00000000e+00 -8.31492966e-04]
#  [ 0.00000000e+00  0.00000000e+00  1.00000000e+00  1.97260967e-01]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2045
# TICKS UNSIGNED 2045
# Servo 7 commanded to 3.138 rad (2045 ticks)
# WRITING TICKS SIGNED:  179
# TICKS UNSIGNED 179
# Servo 8 commanded to 0.275 rad (179 ticks)
# WRITING TICKS SIGNED:  169
# TICKS UNSIGNED 169
# Servo 9 commanded to 0.259 rad (169 ticks)
# WRITING TICKS SIGNED:  724
# TICKS UNSIGNED 724
# Servo 10 commanded to 1.112 rad (724 ticks)
# WRITING TICKS SIGNED:  132
# TICKS UNSIGNED 132
# Servo 11 commanded to 0.202 rad (132 ticks)
# [-0.08608148 -0.27010614]
# Current joint angles (radians): [179.73632812  20.30273438  26.27929688  63.36914062  11.6015625 ]
# Target pose matrix (meters):
# [[ 1.00000000e+00  0.00000000e+00  0.00000000e+00  2.50000000e-01]
#  [ 0.00000000e+00  1.00000000e+00  0.00000000e+00 -8.60814791e-04]
#  [ 0.00000000e+00  0.00000000e+00  1.00000000e+00  1.97298939e-01]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2045
# TICKS UNSIGNED 2045
# Servo 7 commanded to 3.138 rad (2045 ticks)
# WRITING TICKS SIGNED:  179
# TICKS UNSIGNED 179
# Servo 8 commanded to 0.275 rad (179 ticks)
# WRITING TICKS SIGNED:  168
# TICKS UNSIGNED 168
# Servo 9 commanded to 0.259 rad (168 ticks)
# WRITING TICKS SIGNED:  724
# TICKS UNSIGNED 724
# Servo 10 commanded to 1.112 rad (724 ticks)
# WRITING TICKS SIGNED:  132
# TICKS UNSIGNED 132
# Servo 11 commanded to 0.202 rad (132 ticks)
# [-0.09025087 -0.28410719]
# Current joint angles (radians): [179.73632812  20.30273438  26.27929688  63.36914062  11.6015625 ]
# Target pose matrix (meters):
# [[ 1.00000000e+00  0.00000000e+00  0.00000000e+00  2.50000000e-01]
#  [ 0.00000000e+00  1.00000000e+00  0.00000000e+00 -9.02508684e-04]
#  [ 0.00000000e+00  0.00000000e+00  1.00000000e+00  1.97158928e-01]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2045
# TICKS UNSIGNED 2045
# Servo 7 commanded to 3.138 rad (2045 ticks)
# WRITING TICKS SIGNED:  179
# TICKS UNSIGNED 179
# Servo 8 commanded to 0.275 rad (179 ticks)
# WRITING TICKS SIGNED:  169
# TICKS UNSIGNED 169
# Servo 9 commanded to 0.260 rad (169 ticks)
# WRITING TICKS SIGNED:  725
# TICKS UNSIGNED 725
# Servo 10 commanded to 1.112 rad (725 ticks)
# WRITING TICKS SIGNED:  132
# TICKS UNSIGNED 132
# Servo 11 commanded to 0.202 rad (132 ticks)
# [-0.08958341 -0.25987172]
# Current joint angles (radians): [179.73632812  20.30273438  26.27929688  63.36914062  11.6015625 ]
# Target pose matrix (meters):
# [[ 1.00000000e+00  0.00000000e+00  0.00000000e+00  2.50000000e-01]
#  [ 0.00000000e+00  1.00000000e+00  0.00000000e+00 -8.95834079e-04]
#  [ 0.00000000e+00  0.00000000e+00  1.00000000e+00  1.97401283e-01]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2045
# TICKS UNSIGNED 2045
# Servo 7 commanded to 3.138 rad (2045 ticks)
# WRITING TICKS SIGNED:  179
# TICKS UNSIGNED 179
# Servo 8 commanded to 0.275 rad (179 ticks)
# WRITING TICKS SIGNED:  168
# TICKS UNSIGNED 168
# Servo 9 commanded to 0.258 rad (168 ticks)
# WRITING TICKS SIGNED:  724
# TICKS UNSIGNED 724
# Servo 10 commanded to 1.112 rad (724 ticks)
# WRITING TICKS SIGNED:  132
# TICKS UNSIGNED 132
# Servo 11 commanded to 0.202 rad (132 ticks)
# [-0.10812156 -0.24625044]
# Current joint angles (radians): [179.73632812  20.30273438  26.27929688  63.36914062  11.6015625 ]
# Target pose matrix (meters):
# [[ 1.          0.          0.          0.25      ]
#  [ 0.          1.          0.         -0.00108122]
#  [ 0.          0.          1.          0.1975375 ]
#  [ 0.          0.          0.          1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2045
# TICKS UNSIGNED 2045
# Servo 7 commanded to 3.137 rad (2045 ticks)
# WRITING TICKS SIGNED:  179
# TICKS UNSIGNED 179
# Servo 8 commanded to 0.275 rad (179 ticks)
# WRITING TICKS SIGNED:  167
# TICKS UNSIGNED 167
# Servo 9 commanded to 0.258 rad (167 ticks)
# WRITING TICKS SIGNED:  724
# TICKS UNSIGNED 724
# Servo 10 commanded to 1.111 rad (724 ticks)
# WRITING TICKS SIGNED:  132
# TICKS UNSIGNED 132
# Servo 11 commanded to 0.202 rad (132 ticks)
# [-0.1448108  -0.22247039]
# Current joint angles (radians): [179.73632812  20.30273438  26.27929688  63.36914062  11.6015625 ]
# Target pose matrix (meters):
# [[ 1.          0.          0.          0.25      ]
#  [ 0.          1.          0.         -0.00144811]
#  [ 0.          0.          1.          0.1977753 ]
#  [ 0.          0.          0.          1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2044
# TICKS UNSIGNED 2044
# Servo 7 commanded to 3.136 rad (2044 ticks)
# WRITING TICKS SIGNED:  179
# TICKS UNSIGNED 179
# Servo 8 commanded to 0.275 rad (179 ticks)
# WRITING TICKS SIGNED:  166
# TICKS UNSIGNED 166
# Servo 9 commanded to 0.256 rad (166 ticks)
# WRITING TICKS SIGNED:  724
# TICKS UNSIGNED 724
# Servo 10 commanded to 1.111 rad (724 ticks)
# WRITING TICKS SIGNED:  132
# TICKS UNSIGNED 132
# Servo 11 commanded to 0.202 rad (132 ticks)
# [-0.12903761 -0.18017341]
# Current joint angles (radians): [179.6484375   20.30273438  26.27929688  63.36914062  11.6015625 ]
# Target pose matrix (meters):
# [[ 1.          0.          0.          0.25      ]
#  [ 0.          1.          0.         -0.00129038]
#  [ 0.          0.          1.          0.19819827]
#  [ 0.          0.          0.          1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2044
# TICKS UNSIGNED 2044
# Servo 7 commanded to 3.136 rad (2044 ticks)
# WRITING TICKS SIGNED:  179
# TICKS UNSIGNED 179
# Servo 8 commanded to 0.276 rad (179 ticks)
# WRITING TICKS SIGNED:  165
# TICKS UNSIGNED 165
# Servo 9 commanded to 0.253 rad (165 ticks)
# WRITING TICKS SIGNED:  723
# TICKS UNSIGNED 723
# Servo 10 commanded to 1.110 rad (723 ticks)
# WRITING TICKS SIGNED:  132
# TICKS UNSIGNED 132
# Servo 11 commanded to 0.202 rad (132 ticks)
# [-0.14524016 -0.16903744]
# Current joint angles (radians): [179.6484375   20.30273438  26.27929688  63.36914062  11.6015625 ]
# Target pose matrix (meters):
# [[ 1.          0.          0.          0.25      ]
#  [ 0.          1.          0.         -0.0014524 ]
#  [ 0.          0.          1.          0.19830963]
#  [ 0.          0.          0.          1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2044
# TICKS UNSIGNED 2044
# Servo 7 commanded to 3.136 rad (2044 ticks)
# WRITING TICKS SIGNED:  179
# TICKS UNSIGNED 179
# Servo 8 commanded to 0.276 rad (179 ticks)
# WRITING TICKS SIGNED:  164
# TICKS UNSIGNED 164
# Servo 9 commanded to 0.253 rad (164 ticks)
# WRITING TICKS SIGNED:  723
# TICKS UNSIGNED 723
# Servo 10 commanded to 1.110 rad (723 ticks)
# WRITING TICKS SIGNED:  132
# TICKS UNSIGNED 132
# Servo 11 commanded to 0.202 rad (132 ticks)
# [-0.15800119 -0.15083281]
# Current joint angles (radians): [179.6484375   20.30273438  26.27929688  63.36914062  11.6015625 ]
# Target pose matrix (meters):
# [[ 1.          0.          0.          0.25      ]
#  [ 0.          1.          0.         -0.00158001]
#  [ 0.          0.          1.          0.19849167]
#  [ 0.          0.          0.          1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2043
# TICKS UNSIGNED 2043
# Servo 7 commanded to 3.135 rad (2043 ticks)
# WRITING TICKS SIGNED:  179
# TICKS UNSIGNED 179
# Servo 8 commanded to 0.276 rad (179 ticks)
# WRITING TICKS SIGNED:  164
# TICKS UNSIGNED 164
# Servo 9 commanded to 0.252 rad (164 ticks)
# WRITING TICKS SIGNED:  723
# TICKS UNSIGNED 723
# Servo 10 commanded to 1.109 rad (723 ticks)
# WRITING TICKS SIGNED:  132
# TICKS UNSIGNED 132
# Servo 11 commanded to 0.202 rad (132 ticks)
# [-0.16549809 -0.13221867]
# Current joint angles (radians): [179.56054688  20.30273438  26.27929688  63.36914062  11.6015625 ]
# Target pose matrix (meters):
# [[ 1.          0.          0.          0.25      ]
#  [ 0.          1.          0.         -0.00165498]
#  [ 0.          0.          1.          0.19867781]
#  [ 0.          0.          0.          1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2043
# TICKS UNSIGNED 2043
# Servo 7 commanded to 3.135 rad (2043 ticks)
# WRITING TICKS SIGNED:  179
# TICKS UNSIGNED 179
# Servo 8 commanded to 0.276 rad (179 ticks)
# WRITING TICKS SIGNED:  163
# TICKS UNSIGNED 163
# Servo 9 commanded to 0.251 rad (163 ticks)
# WRITING TICKS SIGNED:  722
# TICKS UNSIGNED 722
# Servo 10 commanded to 1.109 rad (722 ticks)
# WRITING TICKS SIGNED:  132
# TICKS UNSIGNED 132
# Servo 11 commanded to 0.202 rad (132 ticks)
# [-0.18128433 -0.14221643]
# Current joint angles (radians): [179.56054688  20.30273438  26.27929688  63.36914062  11.6015625 ]
# Target pose matrix (meters):
# [[ 1.          0.          0.          0.25      ]
#  [ 0.          1.          0.         -0.00181284]
#  [ 0.          0.          1.          0.19857784]
#  [ 0.          0.          0.          1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2043
# TICKS UNSIGNED 2043
# Servo 7 commanded to 3.134 rad (2043 ticks)
# WRITING TICKS SIGNED:  179
# TICKS UNSIGNED 179
# Servo 8 commanded to 0.276 rad (179 ticks)
# WRITING TICKS SIGNED:  163
# TICKS UNSIGNED 163
# Servo 9 commanded to 0.251 rad (163 ticks)
# WRITING TICKS SIGNED:  723
# TICKS UNSIGNED 723
# Servo 10 commanded to 1.109 rad (723 ticks)
# WRITING TICKS SIGNED:  132
# TICKS UNSIGNED 132
# Servo 11 commanded to 0.202 rad (132 ticks)
# [-0.10208946 -0.11470463]
# Current joint angles (radians): [179.56054688  20.30273438  26.27929688  63.36914062  11.6015625 ]
# Target pose matrix (meters):
# [[ 1.          0.          0.          0.25      ]
#  [ 0.          1.          0.         -0.00102089]
#  [ 0.          0.          1.          0.19885295]
#  [ 0.          0.          0.          1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2045
# TICKS UNSIGNED 2045
# Servo 7 commanded to 3.138 rad (2045 ticks)
# WRITING TICKS SIGNED:  179
# TICKS UNSIGNED 179
# Servo 8 commanded to 0.276 rad (179 ticks)
# WRITING TICKS SIGNED:  162
# TICKS UNSIGNED 162
# Servo 9 commanded to 0.249 rad (162 ticks)
# WRITING TICKS SIGNED:  722
# TICKS UNSIGNED 722
# Servo 10 commanded to 1.109 rad (722 ticks)
# WRITING TICKS SIGNED:  132
# TICKS UNSIGNED 132
# Servo 11 commanded to 0.202 rad (132 ticks)
# [-0.10166038 -0.07198393]
# Current joint angles (radians): [179.73632812  20.30273438  26.27929688  63.36914062  11.6015625 ]
# Target pose matrix (meters):
# [[ 1.          0.          0.          0.25      ]
#  [ 0.          1.          0.         -0.0010166 ]
#  [ 0.          0.          1.          0.19928016]
#  [ 0.          0.          0.          1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2045
# TICKS UNSIGNED 2045
# Servo 7 commanded to 3.138 rad (2045 ticks)
# WRITING TICKS SIGNED:  179
# TICKS UNSIGNED 179
# Servo 8 commanded to 0.276 rad (179 ticks)
# WRITING TICKS SIGNED:  160
# TICKS UNSIGNED 160
# Servo 9 commanded to 0.247 rad (160 ticks)
# WRITING TICKS SIGNED:  722
# TICKS UNSIGNED 722
# Servo 10 commanded to 1.108 rad (722 ticks)
# WRITING TICKS SIGNED:  132
# TICKS UNSIGNED 132
# Servo 11 commanded to 0.202 rad (132 ticks)
# [-0.1074046 -0.0525688]
# Current joint angles (radians): [179.73632812  20.30273438  26.27929688  63.36914062  11.6015625 ]
# Target pose matrix (meters):
# [[ 1.          0.          0.          0.25      ]
#  [ 0.          1.          0.         -0.00107405]
#  [ 0.          0.          1.          0.19947431]
#  [ 0.          0.          0.          1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2045
# TICKS UNSIGNED 2045
# Servo 7 commanded to 3.137 rad (2045 ticks)
# WRITING TICKS SIGNED:  179
# TICKS UNSIGNED 179
# Servo 8 commanded to 0.276 rad (179 ticks)
# WRITING TICKS SIGNED:  160
# TICKS UNSIGNED 160
# Servo 9 commanded to 0.246 rad (160 ticks)
# WRITING TICKS SIGNED:  721
# TICKS UNSIGNED 721
# Servo 10 commanded to 1.107 rad (721 ticks)
# WRITING TICKS SIGNED:  132
# TICKS UNSIGNED 132
# Servo 11 commanded to 0.202 rad (132 ticks)
# [-0.1109995  -0.05402429]
# Current joint angles (radians): [179.73632812  20.30273438  26.27929688  63.36914062  11.6015625 ]
# Target pose matrix (meters):
# [[ 1.          0.          0.          0.25      ]
#  [ 0.          1.          0.         -0.00111   ]
#  [ 0.          0.          1.          0.19945976]
#  [ 0.          0.          0.          1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2045
# TICKS UNSIGNED 2045
# Servo 7 commanded to 3.137 rad (2045 ticks)
# WRITING TICKS SIGNED:  179
# TICKS UNSIGNED 179
# Servo 8 commanded to 0.276 rad (179 ticks)
# WRITING TICKS SIGNED:  160
# TICKS UNSIGNED 160
# Servo 9 commanded to 0.246 rad (160 ticks)
# WRITING TICKS SIGNED:  721
# TICKS UNSIGNED 721
# Servo 10 commanded to 1.107 rad (721 ticks)
# WRITING TICKS SIGNED:  132
# TICKS UNSIGNED 132
# Servo 11 commanded to 0.202 rad (132 ticks)
# [-0.06795222 -0.03200775]
# Current joint angles (radians): [179.73632812  20.30273438  26.27929688  63.36914062  11.6015625 ]
# Target pose matrix (meters):
# [[ 1.00000000e+00  0.00000000e+00  0.00000000e+00  2.50000000e-01]
#  [ 0.00000000e+00  1.00000000e+00  0.00000000e+00 -6.79522179e-04]
#  [ 0.00000000e+00  0.00000000e+00  1.00000000e+00  1.99679923e-01]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2046
# TICKS UNSIGNED 2046
# Servo 7 commanded to 3.139 rad (2046 ticks)
# WRITING TICKS SIGNED:  179
# TICKS UNSIGNED 179
# Servo 8 commanded to 0.276 rad (179 ticks)
# WRITING TICKS SIGNED:  159
# TICKS UNSIGNED 159
# Servo 9 commanded to 0.244 rad (159 ticks)
# WRITING TICKS SIGNED:  721
# TICKS UNSIGNED 721
# Servo 10 commanded to 1.107 rad (721 ticks)
# WRITING TICKS SIGNED:  132
# TICKS UNSIGNED 132
# Servo 11 commanded to 0.202 rad (132 ticks)
# [0.25862739 0.05061584]
# Current joint angles (radians): [179.82421875  20.30273438  26.27929688  63.36914062  11.6015625 ]
# Target pose matrix (meters):
# [[1.         0.         0.         0.25      ]
#  [0.         1.         0.         0.00258627]
#  [0.         0.         1.         0.20050616]
#  [0.         0.         0.         1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2054
# TICKS UNSIGNED 2054
# Servo 7 commanded to 3.152 rad (2054 ticks)
# WRITING TICKS SIGNED:  180
# TICKS UNSIGNED 180
# Servo 8 commanded to 0.276 rad (180 ticks)
# WRITING TICKS SIGNED:  155
# TICKS UNSIGNED 155
# Servo 9 commanded to 0.239 rad (155 ticks)
# WRITING TICKS SIGNED:  720
# TICKS UNSIGNED 720
# Servo 10 commanded to 1.105 rad (720 ticks)
# WRITING TICKS SIGNED:  132
# TICKS UNSIGNED 132
# Servo 11 commanded to 0.202 rad (132 ticks)
# [1.75648372 1.5089684 ]
# Current joint angles (radians): [180.08789062  20.30273438  26.27929688  63.36914062  11.6015625 ]
# Target pose matrix (meters):
# [[1.         0.         0.         0.25      ]
#  [0.         1.         0.         0.01756484]
#  [0.         0.         1.         0.21508968]
#  [0.         0.         0.         1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2093
# TICKS UNSIGNED 2093
# Servo 7 commanded to 3.212 rad (2093 ticks)
# WRITING TICKS SIGNED:  186
# TICKS UNSIGNED 186
# Servo 8 commanded to 0.286 rad (186 ticks)
# WRITING TICKS SIGNED:  88
# TICKS UNSIGNED 88
# Servo 9 commanded to 0.136 rad (88 ticks)
# WRITING TICKS SIGNED:  692
# TICKS UNSIGNED 692
# Servo 10 commanded to 1.062 rad (692 ticks)
# WRITING TICKS SIGNED:  132
# TICKS UNSIGNED 132
# Servo 11 commanded to 0.202 rad (132 ticks)
# [4.90166768 4.75260458]
# Current joint angles (radians): [182.54882812  20.30273438  25.04882813  60.90820312  11.6015625 ]
# Target pose matrix (meters):
# [[1.         0.         0.         0.25      ]
#  [0.         1.         0.         0.04901668]
#  [0.         0.         1.         0.24752605]
#  [0.         0.         0.         1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2174
# TICKS UNSIGNED 2174
# Servo 7 commanded to 3.335 rad (2174 ticks)
# WRITING TICKS SIGNED:  214
# TICKS UNSIGNED 214
# Servo 8 commanded to 0.329 rad (214 ticks)
# WRITING TICKS SIGNED:  -105
# TICKS UNSIGNED 4294967191
# Servo 9 commanded to -0.161 rad (4294967191 ticks)
# WRITING TICKS SIGNED:  576
# TICKS UNSIGNED 576
# Servo 10 commanded to 0.885 rad (576 ticks)
# WRITING TICKS SIGNED:  132
# TICKS UNSIGNED 132
# Servo 11 commanded to 0.202 rad (132 ticks)
# [8.56108798 7.86332867]
# Current joint angles (radians): [187.91015625  20.56640625  15.99609375  53.52539062  11.51367188]
# Target pose matrix (meters):
# [[1.         0.         0.         0.25      ]
#  [0.         1.         0.         0.08561088]
#  [0.         0.         1.         0.27863329]
#  [0.         0.         0.         1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2263
# TICKS UNSIGNED 2263
# Servo 7 commanded to 3.472 rad (2263 ticks)
# WRITING TICKS SIGNED:  279
# TICKS UNSIGNED 279
# Servo 8 commanded to 0.428 rad (279 ticks)
# WRITING TICKS SIGNED:  -396
# TICKS UNSIGNED 4294966900
# Servo 9 commanded to -0.609 rad (4294966900 ticks)
# WRITING TICKS SIGNED:  352
# TICKS UNSIGNED 352
# Servo 10 commanded to 0.540 rad (352 ticks)
# WRITING TICKS SIGNED:  131
# TICKS UNSIGNED 131
# Servo 11 commanded to 0.201 rad (131 ticks)
# [12.35323709  9.54874993]
# Current joint angles (radians): [196.69921875  24.52148438  -7.29492188  35.15625     11.6015625 ]
# Target pose matrix (meters):
# [[1.         0.         0.         0.25      ]
#  [0.         1.         0.         0.12353237]
#  [0.         0.         1.         0.2954875 ]
#  [0.         0.         0.         1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  299
# TICKS UNSIGNED 299
# Servo 7 commanded to 0.459 rad (299 ticks)
# WRITING TICKS SIGNED:  -423
# TICKS UNSIGNED 4294966873
# Servo 8 commanded to -0.650 rad (4294966873 ticks)
# WRITING TICKS SIGNED:  -1217
# TICKS UNSIGNED 4294966079
# Servo 9 commanded to -1.867 rad (4294966079 ticks)
# WRITING TICKS SIGNED:  0
# TICKS UNSIGNED 0
# Servo 10 commanded to -0.000 rad (0 ticks)
# WRITING TICKS SIGNED:  132
# TICKS UNSIGNED 132
# Servo 11 commanded to 0.202 rad (132 ticks)
# [14.53741156  9.10330709]
# Current joint angles (radians): [188.4375      18.45703125 -24.43359375  11.6015625   11.51367188]
# Target pose matrix (meters):
# [[1.         0.         0.         0.25      ]
#  [0.         1.         0.         0.14537412]
#  [0.         0.         1.         0.29103307]
#  [0.         0.         0.         1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2391
# TICKS UNSIGNED 2391
# Servo 7 commanded to 3.668 rad (2391 ticks)
# WRITING TICKS SIGNED:  577
# TICKS UNSIGNED 577
# Servo 8 commanded to 0.886 rad (577 ticks)
# WRITING TICKS SIGNED:  -1023
# TICKS UNSIGNED 4294966273
# Servo 9 commanded to -1.571 rad (4294966273 ticks)
# WRITING TICKS SIGNED:  0
# TICKS UNSIGNED 0
# Servo 10 commanded to 0.000 rad (0 ticks)
# WRITING TICKS SIGNED:  131
# TICKS UNSIGNED 131
# Servo 11 commanded to 0.201 rad (131 ticks)
# [13.83949953  7.86934059]
# Current joint angles (radians): [177.01171875  19.77539062 -55.28320312  -2.19726562  11.51367188]
# Target pose matrix (meters):
# [[1.         0.         0.         0.25      ]
#  [0.         1.         0.         0.138395  ]
#  [0.         0.         1.         0.27869341]
#  [0.         0.         0.         1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2377
# TICKS UNSIGNED 2377
# Servo 7 commanded to 3.647 rad (2377 ticks)
# WRITING TICKS SIGNED:  604
# TICKS UNSIGNED 604
# Servo 8 commanded to 0.927 rad (604 ticks)
# WRITING TICKS SIGNED:  -849
# TICKS UNSIGNED 4294966447
# Servo 9 commanded to -1.304 rad (4294966447 ticks)
# WRITING TICKS SIGNED:  313
# TICKS UNSIGNED 313
# Servo 10 commanded to 0.481 rad (313 ticks)
# WRITING TICKS SIGNED:  131
# TICKS UNSIGNED 131
# Servo 11 commanded to 0.201 rad (131 ticks)
# [11.18976496  5.86169982]
# Current joint angles (radians): [199.6875      44.20898438 -82.17773438  17.13867188  11.33789062]
# Target pose matrix (meters):
# [[1.         0.         0.         0.25      ]
#  [0.         1.         0.         0.11189765]
#  [0.         0.         1.         0.258617  ]
#  [0.         0.         0.         1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2322
# TICKS UNSIGNED 2322
# Servo 7 commanded to 3.562 rad (2322 ticks)
# WRITING TICKS SIGNED:  570
# TICKS UNSIGNED 570
# Servo 8 commanded to 0.876 rad (570 ticks)
# WRITING TICKS SIGNED:  -573
# TICKS UNSIGNED 4294966723
# Servo 9 commanded to -0.880 rad (4294966723 ticks)
# WRITING TICKS SIGNED:  634
# TICKS UNSIGNED 634
# Servo 10 commanded to 0.973 rad (634 ticks)
# WRITING TICKS SIGNED:  129
# TICKS UNSIGNED 129
# Servo 11 commanded to 0.198 rad (129 ticks)
# [8.82357041 4.55142842]
# Current joint angles (radians): [206.89453125  52.03125    -60.46875     40.95703125  11.6015625 ]
# Target pose matrix (meters):
# [[1.         0.         0.         0.25      ]
#  [0.         1.         0.         0.0882357 ]
#  [0.         0.         1.         0.24551428]
#  [0.         0.         0.         1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2269
# TICKS UNSIGNED 2269
# Servo 7 commanded to 3.481 rad (2269 ticks)
# WRITING TICKS SIGNED:  420
# TICKS UNSIGNED 420
# Servo 8 commanded to 0.644 rad (420 ticks)
# WRITING TICKS SIGNED:  -280
# TICKS UNSIGNED 4294967016
# Servo 9 commanded to -0.430 rad (4294967016 ticks)
# WRITING TICKS SIGNED:  716
# TICKS UNSIGNED 716
# Servo 10 commanded to 1.099 rad (716 ticks)
# WRITING TICKS SIGNED:  132
# TICKS UNSIGNED 132
# Servo 11 commanded to 0.202 rad (132 ticks)
# [6.97743441 3.49457682]
# Current joint angles (radians): [201.62109375  47.37304688 -17.75390625  50.80078125  11.6015625 ]
# Target pose matrix (meters):
# [[1.         0.         0.         0.25      ]
#  [0.         1.         0.         0.06977434]
#  [0.         0.         1.         0.23494577]
#  [0.         0.         0.         1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2225
# TICKS UNSIGNED 2225
# Servo 7 commanded to 3.414 rad (2225 ticks)
# WRITING TICKS SIGNED:  298
# TICKS UNSIGNED 298
# Servo 8 commanded to 0.458 rad (298 ticks)
# WRITING TICKS SIGNED:  -102
# TICKS UNSIGNED 4294967194
# Servo 9 commanded to -0.158 rad (4294967194 ticks)
# WRITING TICKS SIGNED:  694
# TICKS UNSIGNED 694
# Servo 10 commanded to 1.065 rad (694 ticks)
# WRITING TICKS SIGNED:  132
# TICKS UNSIGNED 132
# Servo 11 commanded to 0.202 rad (132 ticks)
# [5.55041488 2.67257921]
# Current joint angles (radians): [196.96289062  37.17773437  -2.90039063  54.22851562  11.6015625 ]
# Target pose matrix (meters):
# [[1.         0.         0.         0.25      ]
#  [0.         1.         0.         0.05550415]
#  [0.         0.         1.         0.22672579]
#  [0.         0.         0.         1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2190
# TICKS UNSIGNED 2190
# Servo 7 commanded to 3.360 rad (2190 ticks)
# WRITING TICKS SIGNED:  243
# TICKS UNSIGNED 243
# Servo 8 commanded to 0.374 rad (243 ticks)
# WRITING TICKS SIGNED:  -15
# TICKS UNSIGNED 4294967281
# Servo 9 commanded to -0.024 rad (4294967281 ticks)
# WRITING TICKS SIGNED:  686
# TICKS UNSIGNED 686
# Servo 10 commanded to 1.053 rad (686 ticks)
# WRITING TICKS SIGNED:  132
# TICKS UNSIGNED 132
# Servo 11 commanded to 0.202 rad (132 ticks)
# [4.40383384 2.0229703 ]
# Current joint angles (radians): [193.7109375   27.0703125    0.52734375  56.51367188  11.6015625 ]
# Target pose matrix (meters):
# [[1.         0.         0.         0.25      ]
#  [0.         1.         0.         0.04403834]
#  [0.         0.         1.         0.2202297 ]
#  [0.         0.         0.         1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2161
# TICKS UNSIGNED 2161
# Servo 7 commanded to 3.316 rad (2161 ticks)
# WRITING TICKS SIGNED:  210
# TICKS UNSIGNED 210
# Servo 8 commanded to 0.324 rad (210 ticks)
# WRITING TICKS SIGNED:  39
# TICKS UNSIGNED 39
# Servo 9 commanded to 0.060 rad (39 ticks)
# WRITING TICKS SIGNED:  682
# TICKS UNSIGNED 682
# Servo 10 commanded to 1.047 rad (682 ticks)
# WRITING TICKS SIGNED:  132
# TICKS UNSIGNED 132
# Servo 11 commanded to 0.202 rad (132 ticks)
# [3.52230873 1.55427524]
# Current joint angles (radians): [190.98632813  22.23632812   5.09765625  57.65625     11.6015625 ]
# Target pose matrix (meters):
# [[1.         0.         0.         0.25      ]
#  [0.         1.         0.         0.03522309]
#  [0.         0.         1.         0.21554275]
#  [0.         0.         0.         1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2139
# TICKS UNSIGNED 2139
# Servo 7 commanded to 3.282 rad (2139 ticks)
# WRITING TICKS SIGNED:  191
# TICKS UNSIGNED 191
# Servo 8 commanded to 0.294 rad (191 ticks)
# WRITING TICKS SIGNED:  74
# TICKS UNSIGNED 74
# Servo 9 commanded to 0.114 rad (74 ticks)
# WRITING TICKS SIGNED:  680
# TICKS UNSIGNED 680
# Servo 10 commanded to 1.043 rad (680 ticks)
# WRITING TICKS SIGNED:  132
# TICKS UNSIGNED 132
# Servo 11 commanded to 0.202 rad (132 ticks)
# [2.83304487 1.18063168]
# Current joint angles (radians): [188.7890625   20.91796875  10.28320312  57.56835938  11.51367188]
# Target pose matrix (meters):
# [[1.         0.         0.         0.25      ]
#  [0.         1.         0.         0.02833045]
#  [0.         0.         1.         0.21180632]
#  [0.         0.         0.         1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2121
# TICKS UNSIGNED 2121
# Servo 7 commanded to 3.254 rad (2121 ticks)
# WRITING TICKS SIGNED:  177
# TICKS UNSIGNED 177
# Servo 8 commanded to 0.273 rad (177 ticks)
# WRITING TICKS SIGNED:  99
# TICKS UNSIGNED 99
# Servo 9 commanded to 0.152 rad (99 ticks)
# WRITING TICKS SIGNED:  676
# TICKS UNSIGNED 676
# Servo 10 commanded to 1.038 rad (676 ticks)
# WRITING TICKS SIGNED:  131
# TICKS UNSIGNED 131
# Servo 11 commanded to 0.201 rad (131 ticks)
# [2.2676079  0.93716579]
# Current joint angles (radians): [187.3828125   20.390625    12.74414062  57.65625     11.51367188]
# Target pose matrix (meters):
# [[1.         0.         0.         0.25      ]
#  [0.         1.         0.         0.02267608]
#  [0.         0.         1.         0.20937166]
#  [0.         0.         0.         1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2106
# TICKS UNSIGNED 2106
# Servo 7 commanded to 3.232 rad (2106 ticks)
# WRITING TICKS SIGNED:  170
# TICKS UNSIGNED 170
# Servo 8 commanded to 0.262 rad (170 ticks)
# WRITING TICKS SIGNED:  114
# TICKS UNSIGNED 114
# Servo 9 commanded to 0.176 rad (114 ticks)
# WRITING TICKS SIGNED:  676
# TICKS UNSIGNED 676
# Servo 10 commanded to 1.038 rad (676 ticks)
# WRITING TICKS SIGNED:  131
# TICKS UNSIGNED 131
# Servo 11 commanded to 0.201 rad (131 ticks)
# [1.80608001 0.74636085]
# Current joint angles (radians): [185.80078125  19.77539062  13.0078125   57.56835938  11.51367188]
# Target pose matrix (meters):
# [[1.         0.         0.         0.25      ]
#  [0.         1.         0.         0.0180608 ]
#  [0.         0.         1.         0.20746361]
#  [0.         0.         0.         1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2095
# TICKS UNSIGNED 2095
# Servo 7 commanded to 3.214 rad (2095 ticks)
# WRITING TICKS SIGNED:  165
# TICKS UNSIGNED 165
# Servo 8 commanded to 0.254 rad (165 ticks)
# WRITING TICKS SIGNED:  125
# TICKS UNSIGNED 125
# Servo 9 commanded to 0.193 rad (125 ticks)
# WRITING TICKS SIGNED:  676
# TICKS UNSIGNED 676
# Servo 10 commanded to 1.038 rad (676 ticks)
# WRITING TICKS SIGNED:  131
# TICKS UNSIGNED 131
# Servo 11 commanded to 0.201 rad (131 ticks)
# [1.39987562 0.58026767]
# Current joint angles (radians): [184.83398438  18.89648438  13.0078125   57.56835938  11.51367188]
# Target pose matrix (meters):
# [[1.         0.         0.         0.25      ]
#  [0.         1.         0.         0.01399876]
#  [0.         0.         1.         0.20580268]
#  [0.         0.         0.         1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2084
# TICKS UNSIGNED 2084
# Servo 7 commanded to 3.198 rad (2084 ticks)
# WRITING TICKS SIGNED:  160
# TICKS UNSIGNED 160
# Servo 8 commanded to 0.246 rad (160 ticks)
# WRITING TICKS SIGNED:  135
# TICKS UNSIGNED 135
# Servo 9 commanded to 0.207 rad (135 ticks)
# WRITING TICKS SIGNED:  674
# TICKS UNSIGNED 674
# Servo 10 commanded to 1.035 rad (674 ticks)
# WRITING TICKS SIGNED:  131
# TICKS UNSIGNED 131
# Servo 11 commanded to 0.201 rad (131 ticks)
# [1.08996767 0.41829941]
# Current joint angles (radians): [183.8671875   18.19335938  15.02929688  57.56835938  11.51367188]
# Target pose matrix (meters):
# [[1.         0.         0.         0.25      ]
#  [0.         1.         0.         0.01089968]
#  [0.         0.         1.         0.20418299]
#  [0.         0.         0.         1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2076
# TICKS UNSIGNED 2076
# Servo 7 commanded to 3.185 rad (2076 ticks)
# WRITING TICKS SIGNED:  156
# TICKS UNSIGNED 156
# Servo 8 commanded to 0.240 rad (156 ticks)
# WRITING TICKS SIGNED:  143
# TICKS UNSIGNED 143
# Servo 9 commanded to 0.220 rad (143 ticks)
# WRITING TICKS SIGNED:  672
# TICKS UNSIGNED 672
# Servo 10 commanded to 1.032 rad (672 ticks)
# WRITING TICKS SIGNED:  131
# TICKS UNSIGNED 131
# Servo 11 commanded to 0.201 rad (131 ticks)
# [0.84934472 0.30136479]
# Current joint angles (radians): [183.07617187  18.01757812  16.43554688  57.56835938  11.51367188]
# Target pose matrix (meters):
# [[1.         0.         0.         0.25      ]
#  [0.         1.         0.         0.00849345]
#  [0.         0.         1.         0.20301365]
#  [0.         0.         0.         1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2070
# TICKS UNSIGNED 2070
# Servo 7 commanded to 3.176 rad (2070 ticks)
# WRITING TICKS SIGNED:  153
# TICKS UNSIGNED 153
# Servo 8 commanded to 0.236 rad (153 ticks)
# WRITING TICKS SIGNED:  148
# TICKS UNSIGNED 148
# Servo 9 commanded to 0.228 rad (148 ticks)
# WRITING TICKS SIGNED:  672
# TICKS UNSIGNED 672
# Servo 10 commanded to 1.031 rad (672 ticks)
# WRITING TICKS SIGNED:  131
# TICKS UNSIGNED 131
# Servo 11 commanded to 0.201 rad (131 ticks)
# [0.6629697  0.21802978]
# Current joint angles (radians): [182.37304688  17.75390625  16.69921875  57.56835938  11.51367188]
# Target pose matrix (meters):
# [[1.        0.        0.        0.25     ]
#  [0.        1.        0.        0.0066297]
#  [0.        0.        1.        0.2021803]
#  [0.        0.        0.        1.       ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2065
# TICKS UNSIGNED 2065
# Servo 7 commanded to 3.168 rad (2065 ticks)
# WRITING TICKS SIGNED:  152
# TICKS UNSIGNED 152
# Servo 8 commanded to 0.234 rad (152 ticks)
# WRITING TICKS SIGNED:  152
# TICKS UNSIGNED 152
# Servo 9 commanded to 0.234 rad (152 ticks)
# WRITING TICKS SIGNED:  671
# TICKS UNSIGNED 671
# Servo 10 commanded to 1.030 rad (671 ticks)
# WRITING TICKS SIGNED:  131
# TICKS UNSIGNED 131
# Servo 11 commanded to 0.201 rad (131 ticks)
# [0.48879529 0.13141291]
# Current joint angles (radians): [181.84570312  17.75390625  16.96289062  57.56835938  11.51367188]
# Target pose matrix (meters):
# [[1.         0.         0.         0.25      ]
#  [0.         1.         0.         0.00488795]
#  [0.         0.         1.         0.20131413]
#  [0.         0.         0.         1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2060
# TICKS UNSIGNED 2060
# Servo 7 commanded to 3.161 rad (2060 ticks)
# WRITING TICKS SIGNED:  151
# TICKS UNSIGNED 151
# Servo 8 commanded to 0.232 rad (151 ticks)
# WRITING TICKS SIGNED:  156
# TICKS UNSIGNED 156
# Servo 9 commanded to 0.240 rad (156 ticks)
# WRITING TICKS SIGNED:  672
# TICKS UNSIGNED 672
# Servo 10 commanded to 1.031 rad (672 ticks)
# WRITING TICKS SIGNED:  131
# TICKS UNSIGNED 131
# Servo 11 commanded to 0.201 rad (131 ticks)
# [0.35782142 0.04640855]
# Current joint angles (radians): [181.40625     17.66601562  17.75390625  57.56835938  11.51367188]
# Target pose matrix (meters):
# [[1.         0.         0.         0.25      ]
#  [0.         1.         0.         0.00357821]
#  [0.         0.         1.         0.20046409]
#  [0.         0.         0.         1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2057
# TICKS UNSIGNED 2057
# Servo 7 commanded to 3.156 rad (2057 ticks)
# WRITING TICKS SIGNED:  150
# TICKS UNSIGNED 150
# Servo 8 commanded to 0.231 rad (150 ticks)
# WRITING TICKS SIGNED:  160
# TICKS UNSIGNED 160
# Servo 9 commanded to 0.246 rad (160 ticks)
# WRITING TICKS SIGNED:  672
# TICKS UNSIGNED 672
# Servo 10 commanded to 1.031 rad (672 ticks)
# WRITING TICKS SIGNED:  131
# TICKS UNSIGNED 131
# Servo 11 commanded to 0.201 rad (131 ticks)
# [ 0.2709407  -0.02597907]
# Current joint angles (radians): [180.96679687  17.578125    17.9296875   57.56835938  11.51367188]
# Target pose matrix (meters):
# [[1.         0.         0.         0.25      ]
#  [0.         1.         0.         0.00270941]
#  [0.         0.         1.         0.19974021]
#  [0.         0.         0.         1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2055
# TICKS UNSIGNED 2055
# Servo 7 commanded to 3.152 rad (2055 ticks)
# WRITING TICKS SIGNED:  149
# TICKS UNSIGNED 149
# Servo 8 commanded to 0.229 rad (149 ticks)
# WRITING TICKS SIGNED:  163
# TICKS UNSIGNED 163
# Servo 9 commanded to 0.251 rad (163 ticks)
# WRITING TICKS SIGNED:  672
# TICKS UNSIGNED 672
# Servo 10 commanded to 1.031 rad (672 ticks)
# WRITING TICKS SIGNED:  131
# TICKS UNSIGNED 131
# Servo 11 commanded to 0.201 rad (131 ticks)
# [ 0.15539015 -0.0973235 ]
# Current joint angles (radians): [180.61523437  17.578125    17.9296875   57.56835938  11.51367188]
# Target pose matrix (meters):
# [[1.         0.         0.         0.25      ]
#  [0.         1.         0.         0.0015539 ]
#  [0.         0.         1.         0.19902677]
#  [0.         0.         0.         1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2052
# TICKS UNSIGNED 2052
# Servo 7 commanded to 3.148 rad (2052 ticks)
# WRITING TICKS SIGNED:  148
# TICKS UNSIGNED 148
# Servo 8 commanded to 0.228 rad (148 ticks)
# WRITING TICKS SIGNED:  166
# TICKS UNSIGNED 166
# Servo 9 commanded to 0.255 rad (166 ticks)
# WRITING TICKS SIGNED:  672
# TICKS UNSIGNED 672
# Servo 10 commanded to 1.031 rad (672 ticks)
# WRITING TICKS SIGNED:  131
# TICKS UNSIGNED 131
# Servo 11 commanded to 0.201 rad (131 ticks)
# [ 0.09018548 -0.13929623]
# Current joint angles (radians): [180.43945312  17.578125    17.9296875   57.56835938  11.51367188]
# Target pose matrix (meters):
# [[1.00000000e+00 0.00000000e+00 0.00000000e+00 2.50000000e-01]
#  [0.00000000e+00 1.00000000e+00 0.00000000e+00 9.01854756e-04]
#  [0.00000000e+00 0.00000000e+00 1.00000000e+00 1.98607038e-01]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 1.00000000e+00]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2050
# TICKS UNSIGNED 2050
# Servo 7 commanded to 3.145 rad (2050 ticks)
# WRITING TICKS SIGNED:  148
# TICKS UNSIGNED 148
# Servo 8 commanded to 0.228 rad (148 ticks)
# WRITING TICKS SIGNED:  168
# TICKS UNSIGNED 168
# Servo 9 commanded to 0.258 rad (168 ticks)
# WRITING TICKS SIGNED:  672
# TICKS UNSIGNED 672
# Servo 10 commanded to 1.032 rad (672 ticks)
# WRITING TICKS SIGNED:  131
# TICKS UNSIGNED 131
# Servo 11 commanded to 0.201 rad (131 ticks)
# [ 0.05713457 -0.16344966]
# Current joint angles (radians): [180.17578125  17.49023438  17.9296875   57.56835938  11.51367188]
# Target pose matrix (meters):
# [[1.00000000e+00 0.00000000e+00 0.00000000e+00 2.50000000e-01]
#  [0.00000000e+00 1.00000000e+00 0.00000000e+00 5.71345695e-04]
#  [0.00000000e+00 0.00000000e+00 1.00000000e+00 1.98365503e-01]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 1.00000000e+00]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2049
# TICKS UNSIGNED 2049
# Servo 7 commanded to 3.144 rad (2049 ticks)
# WRITING TICKS SIGNED:  148
# TICKS UNSIGNED 148
# Servo 8 commanded to 0.227 rad (148 ticks)
# WRITING TICKS SIGNED:  169
# TICKS UNSIGNED 169
# Servo 9 commanded to 0.259 rad (169 ticks)
# WRITING TICKS SIGNED:  672
# ...
# WRITING TICKS SIGNED:  222
# TICKS UNSIGNED 222
# Servo 10 commanded to 0.341 rad (222 ticks)
# WRITING TICKS SIGNED:  131
# TICKS UNSIGNED 131
# Servo 11 commanded to 0.201 rad (131 ticks)
# [-1.85133593 -1.18294349]
# Current joint angles (radians): [174.28710938   1.23046875  15.20507812  17.13867188  11.51367188]
# Target pose matrix (meters):
# [[ 1.          0.          0.          0.25      ]
#  [ 0.          1.          0.         -0.01851336]
#  [ 0.          0.          1.          0.18817057]
#  [ 0.          0.          0.          1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  1999
# TICKS UNSIGNED 1999
# Servo 7 commanded to 3.068 rad (1999 ticks)
# WRITING TICKS SIGNED:  -27
# TICKS UNSIGNED 4294967269
# Servo 8 commanded to -0.043 rad (4294967269 ticks)
# WRITING TICKS SIGNED:  105
# TICKS UNSIGNED 105
# Servo 9 commanded to 0.162 rad (105 ticks)
# WRITING TICKS SIGNED:  222
# TICKS UNSIGNED 222
# Servo 10 commanded to 0.342 rad (222 ticks)
# WRITING TICKS SIGNED:  131
# TICKS UNSIGNED 131
# Servo 11 commanded to 0.201 rad (131 ticks)
# [-1.4697507 -0.9959448]
# Current joint angles (radians): [175.078125     1.23046875  15.20507812  17.2265625   11.51367188]
# Target pose matrix (meters):
# [[ 1.          0.          0.          0.25      ]
#  [ 0.          1.          0.         -0.01469751]
#  [ 0.          0.          1.          0.19004055]
#  [ 0.          0.          0.          1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2009
# TICKS UNSIGNED 2009
# Servo 7 commanded to 3.083 rad (2009 ticks)
# WRITING TICKS SIGNED:  -27
# TICKS UNSIGNED 4294967269
# Servo 8 commanded to -0.043 rad (4294967269 ticks)
# WRITING TICKS SIGNED:  102
# TICKS UNSIGNED 102
# Servo 9 commanded to 0.157 rad (102 ticks)
# WRITING TICKS SIGNED:  224
# TICKS UNSIGNED 224
# Servo 10 commanded to 0.344 rad (224 ticks)
# WRITING TICKS SIGNED:  131
# TICKS UNSIGNED 131
# Servo 11 commanded to 0.201 rad (131 ticks)
# [-1.15581246 -0.82730576]
# Current joint angles (radians): [176.04492187   1.23046875  15.20507812  17.2265625   11.51367188]
# Target pose matrix (meters):
# [[ 1.          0.          0.          0.25      ]
#  [ 0.          1.          0.         -0.01155812]
#  [ 0.          0.          1.          0.19172694]
#  [ 0.          0.          0.          1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2017
# TICKS UNSIGNED 2017
# Servo 7 commanded to 3.095 rad (2017 ticks)
# WRITING TICKS SIGNED:  -27
# TICKS UNSIGNED 4294967269
# Servo 8 commanded to -0.042 rad (4294967269 ticks)
# WRITING TICKS SIGNED:  98
# TICKS UNSIGNED 98
# Servo 9 commanded to 0.151 rad (98 ticks)
# WRITING TICKS SIGNED:  225
# TICKS UNSIGNED 225
# Servo 10 commanded to 0.347 rad (225 ticks)
# WRITING TICKS SIGNED:  131
# TICKS UNSIGNED 131
# Servo 11 commanded to 0.201 rad (131 ticks)
# [-0.94136808 -0.70217849]
# Current joint angles (radians): [176.8359375    1.23046875  15.20507812  17.2265625   11.51367188]
# Target pose matrix (meters):
# [[ 1.          0.          0.          0.25      ]
#  [ 0.          1.          0.         -0.00941368]
#  [ 0.          0.          1.          0.19297822]
#  [ 0.          0.          0.          1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2023
# TICKS UNSIGNED 2023
# Servo 7 commanded to 3.104 rad (2023 ticks)
# WRITING TICKS SIGNED:  -26
# TICKS UNSIGNED 4294967270
# Servo 8 commanded to -0.041 rad (4294967270 ticks)
# WRITING TICKS SIGNED:  95
# TICKS UNSIGNED 95
# Servo 9 commanded to 0.147 rad (95 ticks)
# WRITING TICKS SIGNED:  227
# TICKS UNSIGNED 227
# Servo 10 commanded to 0.349 rad (227 ticks)
# WRITING TICKS SIGNED:  131
# TICKS UNSIGNED 131
# Servo 11 commanded to 0.201 rad (131 ticks)
# [-0.78286925 -0.61120868]
# Current joint angles (radians): [177.36328125   1.23046875  15.20507812  17.13867188  11.51367188]
# Target pose matrix (meters):
# [[ 1.          0.          0.          0.25      ]
#  [ 0.          1.          0.         -0.00782869]
#  [ 0.          0.          1.          0.19388791]
#  [ 0.          0.          0.          1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2027
# TICKS UNSIGNED 2027
# Servo 7 commanded to 3.110 rad (2027 ticks)
# WRITING TICKS SIGNED:  -26
# TICKS UNSIGNED 4294967270
# Servo 8 commanded to -0.041 rad (4294967270 ticks)
# WRITING TICKS SIGNED:  92
# TICKS UNSIGNED 92
# Servo 9 commanded to 0.143 rad (92 ticks)
# WRITING TICKS SIGNED:  227
# TICKS UNSIGNED 227
# Servo 10 commanded to 0.349 rad (227 ticks)
# WRITING TICKS SIGNED:  131
# TICKS UNSIGNED 131
# Servo 11 commanded to 0.201 rad (131 ticks)
# [-0.66577091 -0.52848363]
# Current joint angles (radians): [177.890625     1.23046875  15.20507812  17.13867188  11.51367188]
# Target pose matrix (meters):
# [[ 1.          0.          0.          0.25      ]
#  [ 0.          1.          0.         -0.00665771]
#  [ 0.          0.          1.          0.19471516]
#  [ 0.          0.          0.          1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2030
# TICKS UNSIGNED 2030
# Servo 7 commanded to 3.115 rad (2030 ticks)
# WRITING TICKS SIGNED:  -26
# TICKS UNSIGNED 4294967270
# Servo 8 commanded to -0.040 rad (4294967270 ticks)
# WRITING TICKS SIGNED:  90
# TICKS UNSIGNED 90
# Servo 9 commanded to 0.139 rad (90 ticks)
# WRITING TICKS SIGNED:  227
# TICKS UNSIGNED 227
# Servo 10 commanded to 0.349 rad (227 ticks)
# WRITING TICKS SIGNED:  131
# TICKS UNSIGNED 131
# Servo 11 commanded to 0.201 rad (131 ticks)
# [-0.54992759 -0.4429476 ]
# Current joint angles (radians): [178.33007813   1.23046875  15.20507812  17.2265625   11.51367188]
# Target pose matrix (meters):
# [[ 1.          0.          0.          0.25      ]
#  [ 0.          1.          0.         -0.00549928]
#  [ 0.          0.          1.          0.19557052]
#  [ 0.          0.          0.          1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2033
# TICKS UNSIGNED 2033
# Servo 7 commanded to 3.120 rad (2033 ticks)
# WRITING TICKS SIGNED:  -25
# TICKS UNSIGNED 4294967271
# Servo 8 commanded to -0.039 rad (4294967271 ticks)
# WRITING TICKS SIGNED:  89
# TICKS UNSIGNED 89
# Servo 9 commanded to 0.137 rad (89 ticks)
# WRITING TICKS SIGNED:  230
# TICKS UNSIGNED 230
# Servo 10 commanded to 0.353 rad (230 ticks)
# WRITING TICKS SIGNED:  131
# TICKS UNSIGNED 131
# Servo 11 commanded to 0.201 rad (131 ticks)
# [-0.45768559 -0.41214964]
# Current joint angles (radians): [178.59375      1.23046875  15.20507812  17.13867188  11.51367188]
# Target pose matrix (meters):
# [[ 1.          0.          0.          0.25      ]
#  [ 0.          1.          0.         -0.00457686]
#  [ 0.          0.          1.          0.1958785 ]
#  [ 0.          0.          0.          1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2036
# TICKS UNSIGNED 2036
# Servo 7 commanded to 3.123 rad (2036 ticks)
# WRITING TICKS SIGNED:  -25
# TICKS UNSIGNED 4294967271
# Servo 8 commanded to -0.039 rad (4294967271 ticks)
# WRITING TICKS SIGNED:  87
# TICKS UNSIGNED 87
# Servo 9 commanded to 0.135 rad (87 ticks)
# WRITING TICKS SIGNED:  229
# TICKS UNSIGNED 229
# Servo 10 commanded to 0.352 rad (229 ticks)
# WRITING TICKS SIGNED:  131
# TICKS UNSIGNED 131
# Servo 11 commanded to 0.201 rad (131 ticks)
# [-0.41587042 -0.3657168 ]
# Current joint angles (radians): [178.85742188   1.23046875  15.20507812  17.13867188  11.51367188]
# Target pose matrix (meters):
# [[ 1.          0.          0.          0.25      ]
#  [ 0.          1.          0.         -0.0041587 ]
#  [ 0.          0.          1.          0.19634283]
#  [ 0.          0.          0.          1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2037
# TICKS UNSIGNED 2037
# Servo 7 commanded to 3.125 rad (2037 ticks)
# WRITING TICKS SIGNED:  -25
# TICKS UNSIGNED 4294967271
# Servo 8 commanded to -0.038 rad (4294967271 ticks)
# WRITING TICKS SIGNED:  86
# TICKS UNSIGNED 86
# Servo 9 commanded to 0.133 rad (86 ticks)
# WRITING TICKS SIGNED:  229
# TICKS UNSIGNED 229
# Servo 10 commanded to 0.352 rad (229 ticks)
# WRITING TICKS SIGNED:  131
# TICKS UNSIGNED 131
# Servo 11 commanded to 0.201 rad (131 ticks)
# [-0.40314411 -0.35837178]
# Current joint angles (radians): [179.03320312   1.23046875  15.20507812  17.2265625   11.51367188]
# Target pose matrix (meters):
# [[ 1.          0.          0.          0.25      ]
#  [ 0.          1.          0.         -0.00403144]
#  [ 0.          0.          1.          0.19641628]
#  [ 0.          0.          0.          1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2037
# TICKS UNSIGNED 2037
# Servo 7 commanded to 3.125 rad (2037 ticks)
# WRITING TICKS SIGNED:  -24
# TICKS UNSIGNED 4294967272
# Servo 8 commanded to -0.038 rad (4294967272 ticks)
# WRITING TICKS SIGNED:  86
# TICKS UNSIGNED 86
# Servo 9 commanded to 0.133 rad (86 ticks)
# WRITING TICKS SIGNED:  230
# TICKS UNSIGNED 230
# Servo 10 commanded to 0.353 rad (230 ticks)
# WRITING TICKS SIGNED:  131
# TICKS UNSIGNED 131
# Servo 11 commanded to 0.201 rad (131 ticks)
# [-0.38083779 -0.34496595]
# Current joint angles (radians): [179.03320312   1.23046875  15.20507812  17.2265625   11.51367188]
# Target pose matrix (meters):
# [[ 1.          0.          0.          0.25      ]
#  [ 0.          1.          0.         -0.00380838]
#  [ 0.          0.          1.          0.19655034]
#  [ 0.          0.          0.          1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2038
# TICKS UNSIGNED 2038
# Servo 7 commanded to 3.126 rad (2038 ticks)
# WRITING TICKS SIGNED:  -24
# TICKS UNSIGNED 4294967272
# Servo 8 commanded to -0.038 rad (4294967272 ticks)
# WRITING TICKS SIGNED:  86
# TICKS UNSIGNED 86
# Servo 9 commanded to 0.132 rad (86 ticks)
# WRITING TICKS SIGNED:  230
# TICKS UNSIGNED 230
# Servo 10 commanded to 0.354 rad (230 ticks)
# WRITING TICKS SIGNED:  131
# TICKS UNSIGNED 131
# Servo 11 commanded to 0.201 rad (131 ticks)
# [-0.32804165 -0.31899405]
# Current joint angles (radians): [179.12109375   1.23046875  15.20507812  17.2265625   11.51367188]
# Target pose matrix (meters):
# [[ 1.          0.          0.          0.25      ]
#  [ 0.          1.          0.         -0.00328042]
#  [ 0.          0.          1.          0.19681006]
#  [ 0.          0.          0.          1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2039
# TICKS UNSIGNED 2039
# Servo 7 commanded to 3.128 rad (2039 ticks)
# WRITING TICKS SIGNED:  -24
# TICKS UNSIGNED 4294967272
# Servo 8 commanded to -0.038 rad (4294967272 ticks)
# WRITING TICKS SIGNED:  85
# TICKS UNSIGNED 85
# Servo 9 commanded to 0.131 rad (85 ticks)
# WRITING TICKS SIGNED:  230
# TICKS UNSIGNED 230
# Servo 10 commanded to 0.354 rad (230 ticks)
# WRITING TICKS SIGNED:  131
# TICKS UNSIGNED 131
# Servo 11 commanded to 0.201 rad (131 ticks)
# [-0.29963801 -0.31994382]
# Current joint angles (radians): [179.20898438   1.23046875  15.20507812  17.13867188  11.51367188]
# Target pose matrix (meters):
# [[ 1.          0.          0.          0.25      ]
#  [ 0.          1.          0.         -0.00299638]
#  [ 0.          0.          1.          0.19680056]
#  [ 0.          0.          0.          1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2040
# TICKS UNSIGNED 2040
# Servo 7 commanded to 3.130 rad (2040 ticks)
# WRITING TICKS SIGNED:  -24
# TICKS UNSIGNED 4294967272
# Servo 8 commanded to -0.038 rad (4294967272 ticks)
# WRITING TICKS SIGNED:  85
# TICKS UNSIGNED 85
# Servo 9 commanded to 0.131 rad (85 ticks)
# WRITING TICKS SIGNED:  229
# TICKS UNSIGNED 229
# Servo 10 commanded to 0.352 rad (229 ticks)
# WRITING TICKS SIGNED:  131
# TICKS UNSIGNED 131
# Servo 11 commanded to 0.201 rad (131 ticks)
# [-0.31922161 -0.31482457]
# Current joint angles (radians): [179.296875     1.23046875  15.20507812  17.13867188  11.51367188]
# Target pose matrix (meters):
# [[ 1.          0.          0.          0.25      ]
#  [ 0.          1.          0.         -0.00319222]
#  [ 0.          0.          1.          0.19685175]
#  [ 0.          0.          0.          1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2039
# TICKS UNSIGNED 2039
# Servo 7 commanded to 3.129 rad (2039 ticks)
# WRITING TICKS SIGNED:  -24
# TICKS UNSIGNED 4294967272
# Servo 8 commanded to -0.038 rad (4294967272 ticks)
# WRITING TICKS SIGNED:  84
# TICKS UNSIGNED 84
# Servo 9 commanded to 0.130 rad (84 ticks)
# WRITING TICKS SIGNED:  229
# TICKS UNSIGNED 229
# Servo 10 commanded to 0.353 rad (229 ticks)
# WRITING TICKS SIGNED:  131
# TICKS UNSIGNED 131
# Servo 11 commanded to 0.201 rad (131 ticks)
# [-0.3326396  -0.27784181]
# Current joint angles (radians): [179.12109375   1.23046875  15.20507812  17.2265625   11.51367188]
# Target pose matrix (meters):
# [[ 1.          0.          0.          0.25      ]
#  [ 0.          1.          0.         -0.0033264 ]
#  [ 0.          0.          1.          0.19722158]
#  [ 0.          0.          0.          1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2039
# TICKS UNSIGNED 2039
# Servo 7 commanded to 3.128 rad (2039 ticks)
# WRITING TICKS SIGNED:  -24
# TICKS UNSIGNED 4294967272
# Servo 8 commanded to -0.037 rad (4294967272 ticks)
# WRITING TICKS SIGNED:  84
# TICKS UNSIGNED 84
# Servo 9 commanded to 0.129 rad (84 ticks)
# WRITING TICKS SIGNED:  231
# TICKS UNSIGNED 231
# Servo 10 commanded to 0.354 rad (231 ticks)
# WRITING TICKS SIGNED:  131
# TICKS UNSIGNED 131
# Servo 11 commanded to 0.201 rad (131 ticks)
# [-0.30217132 -0.24659394]
# Current joint angles (radians): [179.20898438   1.23046875  15.20507812  17.13867188  11.51367188]
# Target pose matrix (meters):
# [[ 1.          0.          0.          0.25      ]
#  [ 0.          1.          0.         -0.00302171]
#  [ 0.          0.          1.          0.19753406]
#  [ 0.          0.          0.          1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2040
# TICKS UNSIGNED 2040
# Servo 7 commanded to 3.130 rad (2040 ticks)
# WRITING TICKS SIGNED:  -24
# TICKS UNSIGNED 4294967272
# Servo 8 commanded to -0.037 rad (4294967272 ticks)
# WRITING TICKS SIGNED:  82
# TICKS UNSIGNED 82
# Servo 9 commanded to 0.127 rad (82 ticks)
# WRITING TICKS SIGNED:  230
# TICKS UNSIGNED 230
# Servo 10 commanded to 0.353 rad (230 ticks)
# WRITING TICKS SIGNED:  131
# TICKS UNSIGNED 131
# Servo 11 commanded to 0.201 rad (131 ticks)
# [-0.30628702 -0.25034095]
# Current joint angles (radians): [179.296875     1.23046875  15.20507812  17.13867188  11.51367188]
# Target pose matrix (meters):
# [[ 1.          0.          0.          0.25      ]
#  [ 0.          1.          0.         -0.00306287]
#  [ 0.          0.          1.          0.19749659]
#  [ 0.          0.          0.          1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2040
# TICKS UNSIGNED 2040
# Servo 7 commanded to 3.129 rad (2040 ticks)
# WRITING TICKS SIGNED:  -24
# TICKS UNSIGNED 4294967272
# Servo 8 commanded to -0.037 rad (4294967272 ticks)
# WRITING TICKS SIGNED:  83
# TICKS UNSIGNED 83
# Servo 9 commanded to 0.127 rad (83 ticks)
# WRITING TICKS SIGNED:  230
# TICKS UNSIGNED 230
# Servo 10 commanded to 0.353 rad (230 ticks)
# WRITING TICKS SIGNED:  131
# TICKS UNSIGNED 131
# Servo 11 commanded to 0.201 rad (131 ticks)
# [-0.36378792 -0.27130561]
# Current joint angles (radians): [179.296875     1.23046875  15.20507812  17.2265625   11.51367188]
# Target pose matrix (meters):
# [[ 1.          0.          0.          0.25      ]
#  [ 0.          1.          0.         -0.00363788]
#  [ 0.          0.          1.          0.19728694]
#  [ 0.          0.          0.          1.        ]]
#
# Calculated joint angles (radians) for target position:
# WRITING TICKS SIGNED:  2038
# TICKS UNSIGNED 2038
# Servo 7 commanded to 3.127 rad (2038 ticks)
# WRITING TICKS SIGNED:  -24
# TICKS UNSIGNED 4294967272
# Servo 8 commanded to -0.037 rad (4294967272 ticks)
# WRITING TICKS SIGNED:  84
# TICKS UNSIGNED 84
# Servo 9 commanded to 0.129 rad (84 ticks)
# WRITING TICKS SIGNED:  231
# TICKS UNSIGNED 231
# Servo 10 commanded to 0.355 rad (231 ticks)
# WRITING TICKS SIGNED:  131
# TICKS UNSIGNED 131
# Servo 11 commanded to 0.201 rad (131 ticks)
